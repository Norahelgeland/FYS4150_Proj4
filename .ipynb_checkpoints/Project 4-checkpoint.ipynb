# %% [markdown]
# # Project 4

# %% [markdown]
# Task 5

# %% [markdown]
# ##### Start with all spins beieng positive

# %% [markdown]
# Temprature T = 1

# %% [markdown]
# Read the data

# %%
import matplotlib.pyplot as plt
  
exp_e_pos_1 = []
exp_m_pos_1 = []
for line in open('Exp_e_m_1.txt', 'r'):
    lines = [i for i in line.split()]
    exp_e_pos_1.append(float(lines[0]))
    exp_m_pos_1.append(float(lines[1]))

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('E[ε] plotted for number of cycles, initialized with all positiv spins, T=1', fontsize=15)
plt.xlabel('Cycles', fontsize=15)
plt.ylabel('E[ε]', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_e_pos_1)
#plt.savefig('e_INIT_pos_T_1.pdf')
plt.show()

# %% [markdown]
# Make excpectation values for the energy

# %%
fig = plt.figure(figsize=(8, 6))
plt.title('E[m] plotted for number of cycles, initialized with all positiv spins, T=1', fontsize=15)
plt.xlabel('Cycles', fontsize=15)
plt.ylabel('E[m]', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_m_pos_1)
#plt.savefig('e_INIT_pos_T_1.pdf')
plt.show()

# %% [markdown]
# Temprature T = 2.4

# %%
import matplotlib.pyplot as plt
  
exp_e_pos_2_4 = []
exp_m_pos_2_4 = []
for line in open('Exp_e_m_2.4.txt', 'r'):
    lines = [i for i in line.split()]
    exp_e_pos_2_4.append(float(lines[0]))
    exp_m_pos_2_4.append(float(lines[1]))

# %%
      
fig = plt.figure()
plt.title('Expectation value ε for cycles, start with only positiv spins, T=2.4', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value ε', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_e_pos_2_4)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Expectation value m for cycles, start with only positiv spins, T=2.4', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value m', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_m_pos_2_4)
  
plt.show()

# %% [markdown]
# Starts with random spins

# %%
import matplotlib.pyplot as plt
  
exp_e_rand_1 = []
exp_m_rand_1 = []
for line in open('Exp_e_m_random_1_TEST.txt', 'r'):
    lines = [i for i in line.split()]
    exp_e_rand_1.append(float(lines[0]))
    exp_m_rand_1.append(float(lines[1]))

# %%
fig = plt.figure()
plt.title('Expectation value ε for cycles, start with random spins, T=1', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value ε', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_e_rand_1)
  
plt.show()

# %%
import matplotlib.pyplot as plt
  
exp_e_rand_1 = []
exp_m_rand_1 = []
for line in open('Exp_e_m_random_1.txt', 'r'):
    lines = [i for i in line.split()]
    exp_e_rand_1.append(float(lines[0]))
    exp_m_rand_1.append(float(lines[1]))

# %%
fig = plt.figure()
plt.title('Expectation value ε for cycles, start with random spins, T=1', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value ε', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_e_rand_1)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Expectation value m for cycles, start with random spins, T=1', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value m', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_m_rand_1)
  
plt.show()

# %%
import matplotlib.pyplot as plt

exp_e_rand_2_4 = []
exp_m_rand_2_4 = []
for line in open('Exp_e_m_random_2.4.txt', 'r'):
    lines = [i for i in line.split()]
    exp_e_rand_2_4.append(float(lines[0]))
    exp_m_rand_2_4.append(float(lines[1]))

# %%
fig = plt.figure()
plt.title('Expectation value ε for cycles, start with random spins, T=2.4', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value ε', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_e_rand_2_4)
  
plt.show()

# %%
fig = plt.figure()
plt.title('Expectation value m for cycles, start with random spins, T=2.4', fontsize=15)
plt.xlabel('Cycle', fontsize=15)
plt.ylabel('Expectation value m', fontsize=15)
plt.xscale('symlog')
plt.plot(exp_m_rand_2_4)
  
plt.show()

# %% [markdown]
# ## Plotting them all together

# %%
from IPython.display import display, Math, Latex

plt.rc('text', usetex=True)

fig = plt.figure(figsize=(10, 8))
#plt.title('E[ε] plotted for number of cycles', fontsize=18)
plt.xlabel('MC cycles', fontsize=16)
plt.ylabel(r'$\langle \epsilon \rangle$', fontsize=20, color='black')
plt.xscale('symlog')
plt.grid()
#plt.axes().set_facecolor('')
plt.plot(exp_e_pos_1, label='T = 1, ordered')
plt.plot(exp_e_pos_2_4, label='T = 2.4 , ordered')
plt.plot(exp_e_rand_1, label='T = 1, random')
plt.plot(exp_e_rand_2_4, label='T = 2.4, random')
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=14)
#plt.savefig('e_T_rand_diff.pdf')
plt.show()
# Out:
# /Users/bruker/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.

# %% [markdown]
# ## Histogram of T = 1 and T = 2.4

# %% [markdown]
# T = 2.4

# %%
import matplotlib.pyplot as plt
  
e_pos_2_4 = []
m_pos_2_4 = []
for line in open('MILe_m_2_4.txt', 'r'):
    lines = [i for i in line.split()]
    e_pos_2_4.append(float(lines[0]))
    m_pos_2_4.append(float(lines[1]))

# %%
import matplotlib.pyplot as plt
  
e_pos_2_4 = []
m_pos_2_4 = []
for line in open('MILe_m_2_4_NEW.txt', 'r'):
    lines = [i for i in line.split()]
    e_pos_2_4.append(float(lines[0]))
    m_pos_2_4.append(float(lines[1]))

# %%
import numpy as np
k = np.array(e_pos_2_4[10**(4):])
weights = np.ones_like(k)/float(len(k))
fig = plt.figure(figsize=(10, 8))
plt.hist(k, weights=weights, bins = 300)
#plt.xlim(-1.238,-1.232)
#plt.title('Distribution of ε values for 100 000 MCMC cycles, T = 2.4', fontsize=15)
#plt.axes().set_facecolor('yellow')
plt.xlabel('ε values', fontsize=17)
plt.ylabel('Probability', fontsize=17)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=16)
plt.savefig('Hist_T_2_4.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
  
e_pos_1 = []
m_pos_1 = []
for line in open('Mile_m_1_NEW.txt', 'r'):
    lines = [i for i in line.split()]
    e_pos_1.append(float(lines[0]))
    m_pos_1.append(float(lines[1]))

# %%
import numpy as np
k = np.array(e_pos_1[10**(4):])
weights = np.ones_like(k)/float(len(k))
fig = plt.figure(figsize=(10, 8))
plt.hist(k, weights=weights, bins = 9)
#plt.xlim(-1.238,-1.232)
#plt.title('Distribution of ε values for 100 000 MCMC cycles, T = 1', fontsize=15)
plt.xlabel('ε values', fontsize=17)
plt.ylabel('Probability', fontsize=17)
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=16)
plt.savefig('Hist_T_1.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
df = pd.DataFrame(e_pos_2_4[10**(4):])

# %%
df
# Out:
#            0
# 0      -1.27
# 1      -1.16
# 2      -1.36
# 3      -1.44
# 4      -1.51
# ...      ...
# 989995 -1.11
# 989996 -1.03
# 989997 -1.08
# 989998 -1.24
# 989999 -1.21
#
# [990000 rows x 1 columns]

# %%
import numpy as np
k = np.array(e_pos_2_4[10**(4):])

# %%
k = np.array(e_pos_2_4[10**(4):])
weights = np.ones_like(k)/float(len(k))
fig = plt.figure(figsize=(10, 8))
plt.hist(k, weights=weights, bins = 300)
plt.xlim(-1.238,-1.232)
plt.title('Distribution of ε values for 1 Million MCMC cycles, T = 2.4', fontsize=15)
plt.xlabel('ε values', fontsize=15)
plt.ylabel('probability', fontsize=15)
plt.xticks(size = 14)
plt.yticks(size = 15)
plt.legend(fontsize=15)
plt.savefig('Hist_T_2_4.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
  
e_pos_1 = []
m_pos_1 = []
for line in open('MILe_m_1.txt', 'r'):
    lines = [i for i in line.split()]
    e_pos_1.append(float(lines[0]))
    m_pos_1.append(float(lines[1]))

# %%
import numpy as np

k = np.array(e_pos_1[10**(4):])
weights = np.ones_like(k)/float(len(k))
fig = plt.figure(figsize=(10, 8))
plt.hist(e_pos_1[1:], bins = 100)
plt.xlim(-2.1, -1.9)
plt.title('Distribution of ε values for 1 Million MCMC cycles, T = 1', fontsize=15)
plt.xlabel('ε values', fontsize=15)
plt.ylabel('probability', fontsize=15)
plt.xticks(size = 14)
plt.yticks(size = 15)
plt.legend(fontsize=15)
#plt.savefig('Hist_T_1.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
h = pd.DataFrame(e_pos_1[10**(4):])
#h = h.rename(columns={"0":"a"})

new_names = {'a':'0'}
#h.rename(index=str, columns=new_names)
h.columns = new_names

#names=['Temperature'
h
# Out:
#              a
# 0      -1.9973
# 1      -1.9973
# 2      -1.9973
# 3      -1.9973
# 4      -1.9973
# ...        ...
# 989995 -1.9972
# 989996 -1.9972
# 989997 -1.9972
# 989998 -1.9972
# 989999 -1.9972
#
# [990000 rows x 1 columns]

# %%
import plotly.express as px
import pandas as pd

x = pd.DataFrame(e_pos_1[10**(4):])
new_names = {'ε values':'0'}
x.columns = new_names

fig = px.histogram(x, histnorm='probability', nbins =200, range_x = [-1.99735,-1.9971],
                   labels={'value':'ε values'}, title='Distribution of ε values for 1 Million MCMC cycles, T = 1',
                  width = 900, height = 700)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-8c470da23468> in <module>
# ----> 1 import plotly.express as px
#       2 import pandas as pd
#       3
#       4 x = pd.DataFrame(e_pos_1[10**(4):])
#       5 new_names = {'ε values':'0'}
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# Task 8

# %% [markdown]
# Loading dataframes for the latice sizes; 40, 60, 80 and 100.

# %%
import pandas as pd
data401 = pd.read_csv("L40_new2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data401.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})

data40_zoomed = pd.read_csv("L40_zoomed.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data40_zoomed.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data402 = data401.append(data40_zoomed, ignore_index = True)

data40_zoomed2 = pd.read_csv("L40_zoomed2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data40_zoomed2.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data40 = data402.append(data40_zoomed2, ignore_index = True)
data40
# Out:
#     Temperature      E[e]      E[m]       C_v         X
# 0      2.100000 -1.660262  0.867296  0.015748  0.015449
# 1      2.127273 -1.634032  0.852330  0.016956  0.020096
# 2      2.154545 -1.602072  0.830339  0.018590  0.030417
# 3      2.181818 -1.569409  0.801906  0.021769  6.600349
# 4      2.209091 -1.532100  0.772508  0.023117  0.073947
# 5      2.236364 -1.482412  0.707654  0.028122  0.215818
# 6      2.263636 -1.438150  0.652906  0.030397  3.188332
# 7      2.290909 -1.380024  0.546854  0.032628  3.092302
# 8      2.318182 -1.328186  0.449354  0.030666  2.523212
# 9      2.345455 -1.279504  0.365190  0.025632  1.868672
# 10     2.372727 -1.235754  0.281160  0.021127  1.202225
# 11     2.400000 -1.203776  0.247035  0.018905  0.929282
# 12     2.230000 -1.498543  0.736913  0.026246  0.140229
# 13     2.240909 -1.476129  0.702108  0.029006  4.186766
# 14     2.251818 -1.452786  0.667496  0.030899  2.844177
# 15     2.262727 -1.436084  0.643900  0.029606  2.996821
# ...

# %%
import pandas as pd
data402_mill = pd.read_csv("L40_million.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data402_mill.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})

data40_mill_zoomed = pd.read_csv("L40_million_zoomed.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data40_mill_zoomed.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data401_mill = data402_mill.append(data40_mill_zoomed, ignore_index = True)

data40_mill_zoomed2 = pd.read_csv("L40_million_zoomed2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data40_mill_zoomed2.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data40_mill = data401_mill.append(data40_mill_zoomed2, ignore_index = True)

# %%
plt.plot(data40_mill['Temperature'], data40_mill['C_v'], "ro")
plt.show()
plt.plot(data40['Temperature'], data40['C_v'], "ro")

# %%
import pandas as pd
data601 = pd.read_csv("L60_new.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data601.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data60_zoomed = pd.read_csv("L60_zoomed.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data60_zoomed.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data602 = data601.append(data60_zoomed, ignore_index = True)

data60_zoomed2 = pd.read_csv("L60_zoomed2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data60_zoomed2.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data60 = data602.append(data60_zoomed2, ignore_index = True)
data60
# Out:
#     Temperature      E[e]      E[m]       C_v          X
# 0      2.100000 -1.660455  0.868087  0.034641   0.032605
# 1      2.127273 -1.631320  0.849104  0.038613   0.056623
# 2      2.154545 -1.601547  0.829894  0.042600   0.070886
# 3      2.181818 -1.568559  0.803525  0.048736   0.134340
# 4      2.209091 -1.528149  0.764926  0.056627   0.244552
# 5      2.236364 -1.482770  0.700867  0.070016  15.103487
# 6      2.263636 -1.434605  0.635500  0.073391   2.545645
# 7      2.290909 -1.369126  0.458810  0.080069  14.318440
# 8      2.318182 -1.317806  0.363748  0.066511   9.089348
# 9      2.345455 -1.271787  0.264932  0.054341   5.275386
# 10     2.372727 -1.235279  0.217183  0.047142   3.695858
# 11     2.400000 -1.202303  0.170022  0.041646   2.345177
# 12     2.230000 -1.499580  0.738443  0.059389  25.753887
# 13     2.240909 -1.475707  0.689978  0.070870   0.953071
# 14     2.251818 -1.459220  0.677290  0.069356  27.245634
# ...

# %%
import pandas as pd
data60_mill = pd.read_csv("L60_million.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data60_mill.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
# Out:
# <style  type="text/css" >
#     #T_0d837884_6852_11ed_894d_f40f241dcdb2row0_col0 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row0_col1 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row0_col2 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row0_col3 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row0_col4 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row1_col0 {
#             background-color:  pink;
#             color:  red;
#         }    #T_0d837884_6852_11ed_894d_f40f241dcdb2row1_col1 {
#             background-color:  pink;
#             color:  red;
# ...

# %%
plt.plot(data60_mill['Temperature'], data60_mill['C_v'], 'ro')

# %%
import pandas as pd
data801 = pd.read_csv("L80_new2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data801.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data80_zoomed = pd.read_csv("L80_zoomed.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data80_zoomed.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data802 = data801.append(data80_zoomed, ignore_index = True)
data802

data80_zoomed2 = pd.read_csv("L80_zoomed2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data80_zoomed2.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data803 = data802.append(data80_zoomed2, ignore_index = True)


data80_zoomed3 = pd.read_csv("L80_zoomed3.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data80_zoomed3.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data80 = data803.append(data80_zoomed3, ignore_index = True)
data80
# Out:
#     Temperature      E[e]      E[m]       C_v          X
# 0      2.100000 -1.659863  0.867467  0.061719   0.061067
# 1      2.127273 -1.632754  0.851564  0.066536   0.076048
# 2      2.154545 -1.602810  0.831641  0.074502   0.122196
# 3      2.181818 -1.568066  0.804320  0.082155   0.191339
# 4      2.209091 -1.531644  0.773100  0.094031   0.310220
# 5      2.236364 -1.487016  0.718197  0.113248   1.039781
# 6      2.263636 -1.427973  0.596133  0.150619  48.817832
# 7      2.290909 -1.363552  0.404194  0.150086  35.903867
# 8      2.318182 -1.315965  0.295085  0.118879  19.460563
# 9      2.345455 -1.269619  0.196911  0.089091   9.811500
# 10     2.372727 -1.234458  0.162454  0.084197   6.893823
# 11     2.400000 -1.201796  0.122613  0.073042   3.954380
# 12     2.230000 -1.496085  0.728275  0.109825   0.795086
# 13     2.240909 -1.475666  0.695658  0.119156   1.347275
# 14     2.251818 -1.457594  0.665601  0.129128   2.079584
# ...

# %%
import pandas as pd
data1001 = pd.read_csv("L100_new2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data1001.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data100_zoomed = pd.read_csv("L100_zoomed.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data100_zoomed.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data1002 = data1001.append(data100_zoomed, ignore_index = True)

data100_zoomed2 = pd.read_csv("L100_zoomed2.csv", names=['Temperature', 'E[e]', 'E[m]', 'C_v', 'X'])
data100_zoomed2.style.set_properties(**{'background-color': 'pink',
                           'color': 'red'})
data100 = data1002.append(data100_zoomed2, ignore_index = True)
data100
# Out:
#     Temperature      E[e]      E[m]       C_v           X
# 0      2.100000 -1.660600  0.868250  0.096174    0.092752
# 1      2.127273 -1.632460  0.851096  0.104807    0.128432
# 2      2.154545 -1.601320  0.829132  0.122622    0.228180
# 3      2.181818 -1.568735  0.805353  0.133019    0.303592
# 4      2.209091 -1.529458  0.766495  0.158652    0.826682
# 5      2.236364 -1.482340  0.699868  0.201569    2.700695
# 6      2.263636 -1.428949  0.595193  0.235586    7.456794
# 7      2.290909 -1.364780  0.391864  0.236843   79.090432
# 8      2.318182 -1.311615  0.245121  0.179166   35.098901
# 9      2.345455 -1.269465  0.166009  0.145169   17.713130
# 10     2.372727 -1.234659  0.125692  0.133166   10.502645
# 11     2.400000 -1.202141  0.099188  0.118414    6.472854
# 12     2.230000 -1.495385  0.725411  0.179656    1.363004
# 13     2.240909 -1.478043  0.704678  0.177730    1.477382
# 14     2.251818 -1.455038  0.656660  0.217216    4.445841
# ...

# %% [markdown]
# Energy per spin expectation values

# %%
from IPython.display import display, Math, Latex

plt.rc('text', usetex=True)

fig = plt.figure(figsize=(10, 8))
#plt.title('E[ε] plotted for different temperatures', fontsize=18)
plt.xlabel('Temperatures', fontsize=18)
plt.ylabel(r'$\langle \epsilon \rangle$', fontsize=20)
#plt.xscale('symlog')
plt.grid()
plt.plot(data40_mill['Temperature'], data40_mill['E[e]'], 'co', label='L = 40')
plt.plot(data60['Temperature'], data60['E[e]'], 'ro', label='L=60')
plt.plot(data80['Temperature'], data80['E[e]'], 'go', label='L=80')
plt.plot(data100['Temperature'], data100['E[e]'], 'bo', label='L=100')
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=16)
plt.savefig('E[e]_T.pdf')
plt.show()

# %% [markdown]
# magnetization per spin expectation values

# %%
fig = plt.figure(figsize=(10, 8))
plt.title('E[m] plotted for different temperatures', fontsize=18)
plt.xlabel('Temperatures', fontsize=16)
plt.ylabel(r'$\langle m \rangle$', fontsize=17)
#plt.xscale('symlog')
plt.grid()
plt.plot(data40_mill['Temperature'], data40_mill['E[m]'], 'co', markersize = 7, label='L = 40')
plt.plot(data60['Temperature'], data60['E[m]'], 'ro', markersize = 7,label='L=60')
plt.plot(data80['Temperature'], data80['E[m]'], 'go', markersize = 7, label='L=80')
plt.plot(data100['Temperature'], data100['E[m]'], 'bo', markersize = 7, label='L=100')

plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=16)
plt.savefig('E[m]_T.pdf')
plt.show()

# %% [markdown]
# Heat capacities

# %%
fig = plt.figure(figsize=(10, 8))
plt.title(r'Heat capacity $C_v$ plotted for different temperatures', fontsize=18)
plt.xlabel('temperatures', fontsize=16)
plt.ylabel(r'$C_v$', fontsize=16)
#plt.xscale('symlog')
plt.grid()
plt.plot(data40_mill['Temperature'], data40_mill['C_v'], 'mo', markersize = 7, label='L = 40')
plt.plot(data60_mill['Temperature'], data60_mill['C_v'], 'ro', markersize = 7, label='L=60')
#plt.plot(data80['Temperature'], data80['C_v'], 'go', markersize = 7, label='L=80')
#plt.plot(data100['Temperature'], data100['C_v'], 'co', markersize = 7, label='L=100')
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=14)
#plt.savefig('e_T_rand_diff.pdf')
plt.show()

# %% [markdown]
# Sucseptibility

# %%
fig = plt.figure(figsize=(10, 8))
#plt.title('Susceptibility [X] plotted for different temperatures', fontsize=18)
plt.xlabel('temperatures', fontsize=16)
plt.ylabel('X', fontsize=16)
#plt.xscale('symlog')
plt.grid()
plt.plot(data40_mill['Temperature'], data40_mill['X'], 'co', markersize = 7, label='L = 40')
plt.plot(data60['Temperature'], data60['X'], 'ro', markersize = 7, label='L=60')
plt.plot(data80['Temperature'], data80['X'], 'go', markersize = 7, label='L=80')
plt.plot(data100['Temperature'], data100['X'], 'bo', markersize = 7, label='L=100')
plt.xticks(size = 16)
plt.yticks(size = 16)
plt.legend(fontsize=14)
#plt.savefig('e_T_rand_diff.pdf')
plt.show()

# %% [markdown]
# Finding the critical temperature

# %%
critical40 = data40_mill.iloc[:,[3]].max()
print(data40_mill.idxmax())
crtical60 = data60.iloc[:,[3]].max()
print(data60.idxmax())
crtical80 = data80.iloc[:,[3]].max()
print(data80.idxmax())
crtical100 = data100.iloc[:,[3]].max()
print(data100.idxmax())
# Out:
# Temperature    11
# E[e]           11
# E[m]            0
# C_v            17
# X               3
# dtype: int64
# Temperature    11
# E[e]           11
# E[m]            0
# C_v            29
# X              14
# dtype: int64
# Temperature    11
# E[e]           11
# E[m]            0
# C_v            41
# X              37
# dtype: int64
# Temperature    11
# E[e]           11
# E[m]            0
# C_v            16
# X              29
# dtype: int64

# %%
temp40 = data40.iloc[17,:]
temp60 = data60.iloc[29,:]
temp80 = data80.iloc[41,:]
temp100 = data100.iloc[16,:]

# %%
from sklearn.linear_model import LinearRegression



lat_size = np.array([[1/40], [1/60], [1/80], [1/100]])
crit_vals = np.array([[temp40[3]], [temp60[3]], [temp80[3]], [temp100[3]]])
plt.plot(lat_size, crit_vals)
plt.show()
model = LinearRegression()
model.fit(lat_size, crit_vals, sample_weight = None)
print(model.coef_)
print(model.intercept_)
# Out:
# [[-14.27151622]]
# [0.36580463]

# %%
new = np.array(np.linspace(0,1/100,10)).reshape(-1, 1)
pred = model.predict(new)

# %%
plt.plot(new, pred)
